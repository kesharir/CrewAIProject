# %%
from dotenv import load_dotenv
from crewai import LLM

load_dotenv()
llm = LLM(
    model="google/gemini-2.5-flash-lite",
    temperature=0.1
)
response = llm.call("Who invented bulb")
print(response)
# Out:
# The invention of the light bulb is a bit more complex than a single person inventing it. It's more accurate to say that **Thomas Edison is widely credited with inventing the first commercially successful incandescent light bulb.**
#
# Here's a breakdown of why it's not a simple answer and Edison's crucial role:
#
# *   **Early Pioneers:** Many inventors before Edison experimented with incandescent lighting. They created bulbs that worked, but they had significant drawbacks:
#     *   **Short Lifespan:** The filaments would burn out very quickly.
#     *   **High Cost:** They were expensive to produce.
#     *   **Impracticality:** They weren't reliable enough for widespread use.
#
# *   **Key Predecessors:** Some notable figures include:
#     *   **Humphry Davy (1802):** Demonstrated an electric arc lamp, which produced light but was not an incandescent bulb.
#     *   **Warren de la Rue (1840):** Created a bulb with a platinum filament in a vacuum, but platinum was too expensive.
# ...

# %%
from crewai import Agent, Task, Crew 

email_assistant = Agent(
    role="email_assistant",
    goal="Improve emails and make them sound professional and clear",
    backstory="A highly experience communication expert skilled in professional email writing",
    verbose=True,
    llm=llm
)

original_email = """
hey team, just wanted to tell u that the demo is kind of ready, but there is still stuff left. 
Maybe we can show what we have and say rest is WIP. 
Let me know what you think. thanks
"""

email_task = Task(
    description=f"""Take the following rough email and rewrite it into a professional and polished version.
    Expand abbreviations: '''{original_email}'''
    """,
    agent = email_assistant,
    expected_output="A professional written email with proper formatting and content"
)

crew = Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 4711dec0-b2c4-4c8f-ad16-24842e302dec                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...
