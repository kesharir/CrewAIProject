# %%
from dotenv import load_dotenv
from crewai import LLM

load_dotenv()
llm = LLM(
    model="google/gemini-2.5-flash-lite",
    temperature=0.1
)

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research intersting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data",
    verbose=True,
    llm=llm
)
writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content",
    verbose=True,
    llm=llm
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 68bcf3aa-8971-4781-9297-b49047465386                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  ID: 80265b65-3a42-4aa4-8043-c9e68459d2a6                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 3-5 interesting and recent facts about the future of electric vehicles:                               │
# │                                                                                                                 │
# │  *   **Solid-state batteries are poised to revolutionize EV range and charging times.** Companies like          │
# │  QuantumScape and Toyota are making significant strides in developing solid-state batteries, which promise      │
# │  higher energy density (leading to longer ranges), faster charging capabilities (potentially minutes instead    │
# │  of hours), and improved safety due to the elimination of flammable liquid electrolytes. While mass production  │
# │  is still a few years away, prototypes are demonstrating performance that could fundamentally change the EV     │
# │  landscape.                                                                                                     │
# │                                                                                                                 │
# │  *   **Vehicle-to-Grid (V2G) technology is gaining traction, turning EVs into mobile power sources.** V2G       │
# │  technology allows electric vehicles to not only draw power from the grid but also send it back. This           │
# │  capability can help stabilize the grid by providing power during peak demand, support renewable energy         │
# │  integration by storing excess solar or wind power, and even offer financial benefits to EV owners. Pilot       │
# │  programs and increasing industry interest suggest V2G will become a more common feature in future EVs.         │
# │                                                                                                                 │
# │  *   **The global charging infrastructure is expanding rapidly, addressing range anxiety.** Governments and     │
# │  private companies worldwide are investing heavily in building out charging networks. This includes a mix of    │
# │  fast chargers for highways, Level 2 chargers for homes and workplaces, and even wireless charging solutions.   │
# │  The increasing density and speed of charging options are crucial for widespread EV adoption and are expected   │
# │  to continue their exponential growth.                                                                          │
# │                                                                                                                 │
# │  *   **Autonomous driving technology is increasingly integrated with electric powertrains.** The inherent       │
# │  digital nature of EVs makes them ideal platforms for advanced driver-assistance systems (ADAS) and fully       │
# │  autonomous driving. The combination of electric propulsion, sophisticated sensors, and powerful computing is   │
# │  paving the way for a future where EVs can navigate and operate with minimal human intervention, further        │
# │  enhancing convenience and safety.                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  ID: 7ad7d8b5-2739-4a7f-9676-1159c0558b41                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electric vehicles is electrifying! Get ready for a revolution powered by solid-state batteries,  │
# │  promising longer ranges and lightning-fast charging. Imagine topping up your EV in minutes, not hours! Beyond  │
# │  just driving, your EV could become a mobile power source thanks to Vehicle-to-Grid (V2G) technology, helping   │
# │  stabilize our energy grid and even earning you money. Don't worry about range anxiety; the charging            │
# │  infrastructure is expanding at an incredible pace, making EV ownership more convenient than ever. Plus, the    │
# │  integration of autonomous driving technology means your future EV could soon be handling the driving for you.  │
# │  The road ahead for EVs is bright, efficient, and incredibly smart!                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 68bcf3aa-8971-4781-9297-b49047465386                                                                       │
# │  Final Output: The future of electric vehicles is electrifying! Get ready for a revolution powered by           │
# │  solid-state batteries, promising longer ranges and lightning-fast charging. Imagine topping up your EV in      │
# │  minutes, not hours! Beyond just driving, your EV could become a mobile power source thanks to Vehicle-to-Grid  │
# │  (V2G) technology, helping stabilize our energy grid and even earning you money. Don't worry about range        │
# │  anxiety; the charging infrastructure is expanding at an incredible pace, making EV ownership more convenient   │
# │  than ever. Plus, the integration of autonomous driving technology means your future EV could soon be handling  │
# │  the driving for you. The road ahead for EVs is bright, efficient, and incredibly smart!                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# CrewOutput(raw="The future of electric vehicles is electrifying! Get ready for a revolution powered by solid-state batteries, promising longer ranges and lightning-fast charging. Imagine topping up your EV in minutes, not hours! Beyond just driving, your EV could become a mobile power source thanks to Vehicle-to-Grid (V2G) technology, helping stabilize our energy grid and even earning you money. Don't worry about range anxiety; the charging infrastructure is expanding at an incredible pace, making EV ownership more convenient than ever. Plus, the integration of autonomous driving technology means your future EV could soon be handling the driving for you. The road ahead for EVs is bright, efficient, and incredibly smart!", pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles.', name='Find 3-5 interesting and recent facts about The future of electrical vehicles.', expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw='Here are 3-5 interesting and recent facts about the future of electric vehicles:\n\n*   **Solid-state batteries are poised to revolutionize EV range and charging times.** Companies like QuantumScape and Toyota are making significant strides in developing solid-state batteries, which promise higher energy density (leading to longer ranges), faster charging capabilities (potentially minutes instead of hours), and improved safety due to the elimination of flammable liquid electrolytes. While mass production is still a few years away, prototypes are demonstrating performance that could fundamentally change the EV landscape.\n\n*   **Vehicle-to-Grid (V2G) technology is gaining traction, turning EVs into mobile power sources.** V2G technology allows electric vehicles to not only draw power from the grid but also send it back. This capability can help stabilize the grid by providing power during peak demand, support renewable energy integration by storing excess solar or wind power, and even offer financial benefits to EV owners. Pilot programs and increasing industry interest suggest V2G will become a more common feature in future EVs.\n\n*   **The global charging infrastructure is expanding rapidly, addressing range anxiety.** Governments and private companies worldwide are investing heavily in building out charging networks. This includes a mix of fast chargers for highways, Level 2 chargers for homes and workplaces, and even wireless charging solutions. The increasing density and speed of charging options are crucial for widespread EV adoption and are expected to continue their exponential growth.\n\n*   **Autonomous driving technology is increasingly integrated with electric powertrains.** The inherent digital nature of EVs makes them ideal platforms for advanced driver-assistance systems (ADAS) and fully autonomous driving. The combination of electric propulsion, sophisticated sensors, and powerful computing is paving the way for a future where EVs can navigate and operate with minimal human intervention, further enhancing convenience and safety.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data\nYour personal goal is: Research intersting facts about the topic: The future of electrical vehicles'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nProvide your complete response:'}, {'role': 'assistant', 'content': 'Here are 3-5 interesting and recent facts about the future of electric vehicles:\n\n*   **Solid-state batteries are poised to revoluti ...
